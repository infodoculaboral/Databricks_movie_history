# %% [markdown]
# ###Spark Filter Transformation

# %%
# %run "../includes/configuration"

# %%
movies_df = spark.read.parquet(f"{silver_folder_path}/movies")

# %%
display(movies_df)

# %%
movies_filtered_df = movies_df.filter(movies_df["movie_id"] == 38)

# %%
movies_filtered_df = movies_df.filter("movie_id = 38")

# %%
display(movies_filtered_df)

# %%
movies_where_df = movies_df.where("movie_id = 38")

# %%
display(movies_where_df)
