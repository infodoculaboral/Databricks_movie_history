# %% [markdown]
# ####Objetivos
# 1. Crear una **"Tabla Administrada (Managed Table)"** con Python
# 2. Crear una **"Tabla Administrada (Managed Table)"** con SQL
# 3. Efecto de eliminar una Tabla Administrada
# 4. Describir **(Describe)** la Tabla

# %%
# %run "../includes/configuration"

# %%
results_movie_genres_languages = spark.read.parquet(f"{gold_folder_path}/results_movie_genres_languages")

# %%
display(results_movie_genres_languages)

# %%
results_movie_genres_languages.write.saveAsTable("demo.results_movie_genres_languages_python")

# %%
# %sql
use demo;
show tables;

# %%
# %sql
describe extended demo.results_movie_genres_languages_python

# %%
# %sql
create table demo.results_movie_genres_languages_sql
as
select * 
  from results_movie_genres_languages_python
  where genre_name = "Adventure"

# %%
# %sql
select * from results_movie_genres_languages_sql

# %%
# %sql
select current_database()

# %%
# %sql
describe extended results_movie_genres_languages_sql

# %%
# %sql
drop table if exists results_movie_genres_languages_sql;

# %%
# %sql
show tables in demo;

# %% [markdown]
# ####Objetivos
# 1. Crear una **"Tabla Externa (External Table)"** con Python
# 2. Crear una **"Tabla Externa (External Table)"** con SQL
# 3. Efecto de eliminación de una **"Tabla Externa (External Table)"**
# 4. Describir **(Describe)** la Tabla

# %%
results_movie_genres_languages.write.format("parquet").option("path", "abfss://mymoviehistory@gold.dfs.core.windows.net/results_movie_genres_py").saveAsTable("demo.results_movie_genres_languages_py2")
#https://mymoviehistory.dfs.core.windows.net/gold/results_movie_genres_languages/
#

# %%
display(gold_folder_path)

# %%
# %sql
describe extended demo.results_movie_genres_languages_py

# %%
# %sql
create table demo.results_movie_genres_languages_sql (
  title string,
  duration_time int,
  release_date date,
  vote_average double,
  language_name string,
  genre_name string,
  created_date timestamp
)
using parquet
location "/mymoviehistory/gold/results_movie_genres_languages_ext_sql"
