# %%
import smtplib
from email.mime.text import MIMEText

subject = 'Pipeline Error'
body = 'El proceso del Pipeline ha caido en error debido a que no se encuentra la carpeta.'
sender = 'infodoculaboral@gmail.com'
my_password = 'elexdnsostzcgqmp'
recipients = [sender, 'sandra.sanz@atmira.com']

def send_mail(subject, body, sender, recipients):
    msg = MIMEText(body)
    msg['subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
        smtp_server.login(sender, my_password)
        smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")

send_mail(subject, body, sender, recipients)
